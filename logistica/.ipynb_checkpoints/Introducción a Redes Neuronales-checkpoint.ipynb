# %% [markdown]
# ![logo](img/itq.png)
#
# # Redes Neuronales y Deep Learning
# ## Clase 02: Introducción a Redes Neuronales
#
# ![logo](img/python_logo.png)
#
# *Anderson Soto*

# %% [markdown]
# ### Sumario
# - Perceptrón
# - Perceptrón multicapa
# - Ejemplo redes AND y XOR
# - Entrenamiento con Backpropagation

# %% [markdown]
# ## Perceptrón Simple
#
# <img src="img/perceptron.png" width="500">
#
# - Propuesto por Rosenblatt 1957

# %% [markdown]
# ### Parámetros:
# - Entrenables, determinan el valor output de la neurona (input * weight + bias):
#   - Bias por cada neurona
#   - Weight por cada conexión

# %% [markdown]
# - A elegir:
#   - Función de activación (cómo se calcula el output en función del input) -> Hiperparámetro

# %% [markdown]
# ## Redes neuronales (Perceptrón simple)
# - Capas de perceptrones, feedforward connection

# %% [markdown]
# #### Red neuronal AND
# - Dos neuronas
# - Output 1 si ambas reciben input 1
#
# <img src="img/tabla_and.png" width="200">

# %% [markdown]
# Función de activación: signo (1 if > 0, else 0)
#
# <img src="img/xor_single_layer.png" width="300">

# %% [markdown]
# W1 = 1, W2 = 1
#
# b = -1.5

# %% [markdown]
# #### Red neuronal XOR
#
# <img src="img/tabla_xor.png" width="200">

# %% [markdown]
# Función de activación: signo (1 if > 0, else 0)
#
# <img src="img/xor_single_layer.png" width="300">

# %% [markdown]
# ¡No tiene solución!
# ¿Y si añadimos una segunda capa oculta? -> Perceptrón Multicapa

# %% [markdown]
# <img src="img/xor_multi_layer.png" width="300">

# %% [markdown]
# ## Ejercicio
# - Averiguar los valores de W1,...,W6 y b1,...,b3 adecuados para XOR

# %% [markdown]
# ## Entrenando ANNs
#
# - **Backpropagation** en general, descenso del gradiente para minimizar la diferencia entre lo esperado (training label) y lo actual (predicción de la red en un instante dado).
# - Inicialización con parámetros aleatorios (https://keras.io/api/layers/initializers/)

# %% [markdown]
# <img src="img/gradient_descent.jpeg" width="400">
#
# Fuente: Menon, 2018.
# URL: https://towardsdatascience.com/linear-regression-using-gradient-descent-97a6c8700931

# %% [markdown]
# ### Training loop
# - Escoger X *training samples* y obtener predicciones
# - Evaluar la función de pérdida
# - Utilizar el error para modificar los parámetros W y b para minimizar el error
# - Parar cuando se llegue a un error aceptable o tras un número de iteraciones (épocas)

# %% [markdown]
# ### Estrategias para actualizar los valores
# - Naive: modificar uno a uno cada parámetro y ver si disminuye o aumenta el error. Ineficiente

# %% [markdown]
# - Diferenciar la capa con respecto a cada parámetro.
#   - Se puede computar el gradiente de la pérdida (derivada) y modificar el parámetro en la dirección contraria

# %% [markdown]
# v- La diferenciación de las primeras capas depende de las últimas.
# Usando la regla de la cadena:
#
# f(g(x)) = f'(g(x)) * g'(x)
#
# El cálculo del gradiente comienza al final de la NN y va hacia atrás (backpropagation).

# %% [markdown]
# ### Tipos de descenso del gradiente
# - Stochastic Gradient Descent: batch size = 1
# - Mini-batch SGD: 1 < batch size < tamaño del training set
# - Batch SGD: batch size = tamaño del training set
