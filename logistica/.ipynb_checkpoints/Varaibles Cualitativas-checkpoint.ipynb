# %% [markdown]
# ![logo](img/itq.png)
#
# ## 10 Variables Cualitativas
#
# ![logo](img/python_logo.png)
#
# *Anderson Soto*

# %%
import numpy as np
import random
random.seed(42)

# %%
nivel_estudios = []
nivel_estudios.extend(['Secundaria']*110)
nivel_estudios.extend(['Bachillerato']*172)
nivel_estudios.extend(['Grado']*145)
nivel_estudios.extend(['Master']*52)
nivel_estudios.extend(['Doctorado']*21)

nivel_estudios = np.random.permutation(nivel_estudios)

# %%
print(nivel_estudios)
# Out:
# ['Grado' 'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado'
#  'Grado' 'Doctorado' 'Secundaria' 'Bachillerato' 'Secundaria' 'Master'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Doctorado' 'Grado' 'Bachillerato'
#  'Secundaria' 'Grado' 'Secundaria' 'Doctorado' 'Bachillerato' 'Secundaria'
#  'Grado' 'Doctorado' 'Master' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Doctorado' 'Grado' 'Bachillerato' 'Secundaria' 'Master'
#  'Master' 'Grado' 'Master' 'Bachillerato' 'Grado' 'Grado' 'Secundaria'
#  'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Doctorado' 'Bachillerato' 'Secundaria' 'Secundaria' 'Secundaria' 'Grado'
#  'Secundaria' 'Secundaria' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Master' 'Secundaria' 'Grado' 'Grado' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Doctorado'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Master' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Grado' 'Grado' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Master' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria' 'Secundaria'
#  'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Grado' 'Secundaria' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Master' 'Grado' 'Master' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Secundaria' 'Grado' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Master' 'Grado' 'Grado' 'Grado'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado'
#  'Grado' 'Master' 'Master' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Grado' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Secundaria' 'Master' 'Grado'
#  'Grado' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Master' 'Secundaria' 'Master'
#  'Bachillerato' 'Bachillerato' 'Master' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Grado' 'Grado' 'Secundaria' 'Secundaria' 'Grado' 'Grado'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Doctorado' 'Grado' 'Grado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Master' 'Grado' 'Secundaria'
#  'Grado' 'Bachillerato' 'Grado' 'Master' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Master' 'Grado' 'Grado' 'Grado' 'Secundaria' 'Grado'
#  'Bachillerato' 'Master' 'Grado' 'Grado' 'Secundaria' 'Grado'
#  'Bachillerato' 'Secundaria' 'Master' 'Grado' 'Bachillerato' 'Grado'
#  'Grado' 'Master' 'Bachillerato' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Master' 'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato'
#  'Doctorado' 'Grado' 'Doctorado' 'Bachillerato' 'Grado' 'Master'
#  'Bachillerato' 'Grado' 'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Master' 'Bachillerato' 'Secundaria' 'Grado' 'Grado'
#  'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Master' 'Master' 'Grado' 'Master' 'Secundaria' 'Secundaria' 'Grado'
#  'Secundaria' 'Grado' 'Secundaria' 'Grado' 'Doctorado' 'Secundaria'
#  'Master' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Master'
#  'Doctorado' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato'
#  'Master' 'Master' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Secundaria' 'Grado' 'Master' 'Doctorado' 'Grado' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Master' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Grado' 'Secundaria' 'Grado' 'Bachillerato' 'Secundaria'
#  'Grado' 'Master' 'Master' 'Bachillerato' 'Grado' 'Master' 'Grado'
#  'Master' 'Master' 'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Grado' 'Grado' 'Secundaria' 'Grado' 'Grado' 'Secundaria' 'Grado'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Doctorado' 'Bachillerato'
#  'Grado' 'Grado' 'Bachillerato' 'Master' 'Bachillerato' 'Master'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Master' 'Secundaria' 'Master' 'Secundaria' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Doctorado' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Doctorado' 'Grado' 'Secundaria' 'Doctorado' 'Bachillerato' 'Secundaria'
#  'Master' 'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Master' 'Grado'
#  'Secundaria' 'Grado' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Doctorado' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Secundaria' 'Doctorado' 'Secundaria' 'Grado'
#  'Doctorado' 'Grado' 'Secundaria' 'Master' 'Secundaria' 'Grado'
#  'Bachillerato' 'Secundaria' 'Grado' 'Grado' 'Master' 'Bachillerato'
#  'Grado' 'Grado' 'Master' 'Grado' 'Bachillerato' 'Grado' 'Secundaria'
#  'Bachillerato' 'Master' 'Master' 'Secundaria' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Master' 'Grado' 'Grado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Grado' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Secundaria' 'Grado'
#  'Doctorado' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Bachillerato']

# %%
estudios, frecuencia = np.unique(nivel_estudios, return_counts=True)
print(estudios, frecuencia)
# Out:
# ['Bachillerato' 'Doctorado' 'Grado' 'Master' 'Secundaria'] [172  21 145  52 110]

# %%
import matplotlib.pyplot as plt

plt.ylabel('Frecuencia absoluta')
plt.xlabel('Nivel de estudios')
plt.title('Diagrama de barras')
plt.bar(estudios, frecuencia)
plt.show()

# %%
colores = {'red', 'blue', 'orange', 'green', 'cyan'}
plt.pie(frecuencia, labels=estudios, colors=colores, autopct='%1.2f%%')
plt.title('Diagrama de sectores')
plt.show()

# %% [markdown]
# # Tarea implementar con pandas esta información

# %%
import pandas as pd

df = pd.DataFrame({'nivel_estudios': nivel_estudios})
frecuencia_pd = df['nivel_estudios'].value_counts()
print(frecuencia_pd)

frecuencia_pd.plot(kind='bar', title='Diagrama de barras con pandas')
plt.show()

frecuencia_pd.plot(kind='pie', autopct='%1.2f%%', title='Diagrama de sectores con pandas')
plt.show()
# Out:
# nivel_estudios
# Bachillerato    172
# Grado           145
# Secundaria      110
# Master           52
# Doctorado        21
# Name: count, dtype: int64

# %% [markdown]
# ## Github
#
# https://github.com/Joji-free/machine2026.git
